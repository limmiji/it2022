# %% [markdown]
# Tutorial 1 (p.25~34)

# %%
# Sequence Types

tu = (23, 'abc', 4.56, (2,3), 'def')            # Tuple : immutable

li = ["abc", 34, 4.34, 23]                      # List : immutable

st = "Hello World"                              # String : mutable

# %%
tu
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
li
# Out:
# ['abc', 34, 4.34, 23]

# %%
st
# Out:
# 'Hello World'

# %%
st = 'Hello World'
st
# Out:
# 'Hello World'

# %%
st = """This is a multi-line string that uses triple quotes."""
st
# Out:
# 'This is a multi-line string that uses triple quotes.'

# %%
tu[1]
# Out:
# 'abc'

# %%
li[1]
# Out:
# 34

# %%
st = "Hello World"
st[1]                      # Second Character in string(문자열은 1하면 두번째가 출력됨 / 0부터 시작 기억)
# Out:
# 'e'

# %%
t = (23, 'abc', 4.56, (2,3), 'def')

# %%
t[1]                    # positive index
# Out:
# 'abc'

# %%
t[-3]                  # negative indices
# Out:
# 4.56

# %%
# Slicing

t[1:4]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1:2]
# Out:
# ('abc', (2, 3))

# %%
t[:2]
# Out:
# (23, 'abc')

# %%
t[2:]
# Out:
# (4.56, (2, 3), 'def')

# %%
t[:]
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
list1 = ['strawberry', 'blueberry', 'kiwi', 'orange', 'apple']

list2 = list1         # 2 names refer to 1 ref
list2                 # Changing one affect both
# Out:
# ['strawberry', 'blueberry', 'kiwi', 'orange', 'apple']

# %%
list2 = list1[:]     # Two independent copies, two refs
list2
# Out:
# ['strawberry', 'blueberry', 'kiwi', 'orange', 'apple']

# %%
t = [1, 2, 4, 5]
3 in t
# Out:
# False

# %%
4 in t
# Out:
# True

# %%
4 not in t
# Out:
# False

# %%
a = 'abcde'
'c' in a
# Out:
# True

# %%
'cd' in a
# Out:
# True

# %%
'ac' in a
# Out:
# False

# %%
(1, 2, 3) + (4, 5, 6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
[1, 2, 3] + [4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
"Hello" + " " + "World"
# Out:
# 'Hello World'
