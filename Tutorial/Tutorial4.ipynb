# %% [markdown]
# Tutorial 4 (p.49~52)

# %%
# True and False

# True : non-zero numbers, non-empty objects
# False : zero, None, empty containers

# X == Y : X and Y have same value (like Jaca equals method)
# X is U : X and Y refer to the exact same object (like Java ==)

# a and b : True if a is True and b is True
# a or b : True if a is True or b is True
# not a : True if a is False

x = true_value if condition else false_value

# lazy evaluation :
# First, condition is evaluated
# If True, true_value is evaluated and returned
# If False, false_value is evaluated and returned
