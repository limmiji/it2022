# %%
x = 34 - 23                         # A comment
y = "Hello"                         # Another one
z = 3.45

if z == 3.45 or y == "Hello":
  x = x + 1
  y = y + " World"                # String concat

print(x)
print(y)                          # 자료는 버전 2라서 print에 괄호 없는디 지금은 버전 3 이라서 print() 참고
# Out:
# 12
# Hello World
